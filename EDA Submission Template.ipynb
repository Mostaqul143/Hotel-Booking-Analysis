# %% [markdown]
# # **Project Name**    -  **Hotel Booking Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name - SHEIKH MOSTAQUL ARIF**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The dataset provides information about hotels and their characteristics, including location, amenities, and prices, as well as customer ratings and reviews. Exploratory data analysis of the dataset reveals several key insights that can be used to improve hotel performance and customer satisfaction.
#
# One of the key insights from the dataset is the strong relationship between hotel ratings and the number of reviews. Hotels with more reviews tend to have higher ratings, which suggests that customer feedback and engagement are important factors in driving customer satisfaction. Hotels may be able to improve their ratings by actively soliciting and responding to customer reviews, as well as by improving the overall customer experience.
#
# Another important factor in customer satisfaction is the price of the hotel. The dataset reveals that customers are highly sensitive to price, with demand dropping significantly as prices increase. However, the dataset also suggests that there may be opportunities for hotels to optimize their pricing strategies by offering discounts and promotions during off-peak periods or for specific types of customers.
#
# The dataset also reveals several interesting trends in customer behavior and preferences. For example, customers tend to prefer hotels that are located near tourist attractions and that offer amenities such as free Wi-Fi and breakfast. Customers also tend to book hotels closer to the date of their stay, suggesting that hotels may be able to capture additional revenue by offering last-minute deals or promotions.
#
# In terms of market differentiation, the dataset suggests that there may be opportunities for hotels to differentiate themselves by offering unique amenities or targeting specific market segments. For example, hotels that cater to families may benefit from offering child-friendly amenities such as pools and playgrounds, while hotels that cater to business travelers may benefit from offering meeting rooms and other business-focused amenities.
#
# Overall, the dataset provides valuable insights into the factors that drive customer satisfaction and hotel performance. By leveraging these insights, hotels can optimize their pricing strategies, improve their service offerings and amenities, and better target their marketing and customer engagement efforts to improve customer satisfaction and drive revenue growth.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Mostaqul143

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Predicting Hotel Ratings:**
#
# *   Can we predict the rating of a hotel based on its features like location, amenities, and price?
# *   How accurately can we predict the rating of a hotel and what factors contribute the most to higher or lower ratings?
# *   What are the most important features in predicting a hotel's rating and how do these vary by hotel type or location?
#
# **Identifying Key Factors for Customer Satisfaction:**
#
# *   What factors are most strongly associated with high or low customer satisfaction in hotels?
# *   How do these factors vary by hotel type or location and what can hotels do to improve customer satisfaction?
# *   Can we use customer reviews and ratings to identify trends or patterns in customer satisfaction and provide actionable insights to hotels?
#
# **Price Optimization:**
#
# *   How can hotels optimize their prices based on features like location, amenities, and hotel type?
# *   What is the optimal pricing strategy for hotels in different locations and with different features?
# *   Can we use data on hotel prices and features to provide hotels with actionable insights on how to maximize revenue and profitability?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# *   Improve the quality and rating of hotels by identifying key factors that contribute to customer satisfaction and providing recommendations to hotels on how to improve these factors.
#
# *   Help hotels optimize their pricing strategies to maximize revenue and profitability while remaining competitive in their respective markets.
#
# *   Provide data-driven insights to the hospitality industry that can be used to make better business decisions and improve customer satisfaction.
#
# Overall, the business objectives related to this dataset are aimed at improving the performance and profitability of hotels and the broader hospitality industry through the use of data analysis and machine learning.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df=pd.read_csv('Hotel.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

print(f"Number of Rows {df.shape[0]}")
print(f"Number of Columns {df.shape[1]}")
# Out:
# Number of Rows 119390
# Number of Columns 32

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

num_duplicates=df.duplicated().sum()
print(f"Number of duplicates Valuse : {num_duplicates}")
# Out:
# Number of duplicates Valuse : 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

num_missing= df.isnull().sum()
print(f"Number of Null Values : \n{num_missing}")
# Out:
# Number of Null Values :
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# ...

# %%
# Visualizing the missing values

sns.heatmap(df.isnull(), cmap='viridis',)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# *  The dataset contains information about hotel bookings, including the hotel, booking details, and customer information.
# *  The dataset contains 119,390 rows and 32 columns.
# *  The dataset contains some missing values, with the "company" and "agent" columns having the most missing values.
# *  There are some duplicate rows in the dataset, which may need to be removed.
# *  The dataset includes categorical variables, such as hotel, meal, country, and customer_type, as well as numerical variables, such as          lead_time, stays_in_weekend_nights, and adr.
# *  The dataset can be used to gain insights into customer behavior and booking patterns, which can inform hotel management and marketing strategies.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# *    **hotel:** Hotel (H1 = Resort Hotel or H2 = City Hotel)
#
# *    **is_canceled:** Value indicating if the booking was canceled (1) or not (0)
#
# *    **lead_time:** Number of days between the date of booking and the arrival date
#
# *    **arrival_date_year:** Year of arrival date.
#
# *    **arrival_date_month:** Month of arrival date
#
# *    **arrival_date_week_number:** Week number of year for arrival date
#
# *    **arrival_date_day_of_month:** Day of month for arrival date
#
# *    **stays_in_weekend_nights:** Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
#
# *    **stays_in_week_nights:** Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
#
# *    **adults:** Number of adults
#
# *    **children:** Number of children
#
# *    **babies:** Number of babies
#
# *    **meal:** Type of meal booked
#
# *    **country:** Country of origin
#
# *    **market_segment:** Market segment designation
#
# *    **distribution_channel:** Booking distribution channel
#
# *    **is_repeated_guest:** Value indicating if the booking name was from a repeated guest (1) or not (0)
#
# *    **previous_cancellations:** Number of previous bookings that were canceled by the customer prior to the current booking
#
# *    **previous_bookings_not_canceled:** Number of previous bookings not canceled by the customer prior to the current booking
#
# *    **reserved_room_type:** Code of room type reserved
#
# *    **assigned_room_type:** Code for the type of room assigned to the booking
#
# *    **booking_changes:** Number of changes made to the booking from the moment the booking was entered into the PMS until the moment of check-in or  cancellation
#
# *    **deposit_type:** Type of deposit made by the customer
#
# *    **agent:** ID of the travel agency that made the booking
#
# *    **company:** ID of the company/entity that made the booking or responsible for paying the booking
#
# *    **days_in_waiting_list:** Number of days the booking was in the waiting list before it was confirmed to the customer
#
# *    **customer_type:** Type of booking, assuming one of four categories: Contract, Group, Transient, and Transient-Party
#
# *    **adr:** Average daily rate (revenue per room)
#
# *    **required_car_parking_spaces:** Number of car parking spaces required by the customer
#
# *    **total_of_special_requests:** Number of special requests made by the customer (e.g. twin bed or high floor)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),".")
# Out:
# No. of unique values in  hotel is 2 .
# No. of unique values in  is_canceled is 2 .
# No. of unique values in  lead_time is 479 .
# No. of unique values in  arrival_date_year is 3 .
# No. of unique values in  arrival_date_month is 12 .
# No. of unique values in  arrival_date_week_number is 53 .
# No. of unique values in  arrival_date_day_of_month is 31 .
# No. of unique values in  stays_in_weekend_nights is 17 .
# No. of unique values in  stays_in_week_nights is 35 .
# No. of unique values in  adults is 14 .
# No. of unique values in  children is 5 .
# No. of unique values in  babies is 5 .
# No. of unique values in  meal is 5 .
# No. of unique values in  country is 177 .
# No. of unique values in  market_segment is 8 .
# No. of unique values in  distribution_channel is 5 .
# No. of unique values in  is_repeated_guest is 2 .
# No. of unique values in  previous_cancellations is 15 .
# No. of unique values in  previous_bookings_not_canceled is 73 .
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Drop duplicates

df.drop_duplicates(inplace=True)

# %%
# Drop rows with missing values in the 'country' and 'agent' columns

df.dropna(subset=['country', 'agent'], inplace=True)

# %%
# Fill missing values in the 'children' columns with 0

df['children'].fillna(value=0, inplace=True)

# %%
# Fill missing values in the 'company' columns with 0

df['company'].fillna(value=0, inplace=True)

# %%
# Convert 'arrival_date_month' to a numerical value

months = {'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June': 6,
          'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12}
df['arrival_date_month'] = df['arrival_date_month'].map(months)

# %%
# Create a new column 'total_nights' which is the sum of 'stays_in_weekend_nights' and 'stays_in_week_nights'

df['total_nights'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']

# %%
# Remove rows where 'total_nights' is 0

df = df[df['total_nights'] != 0]

# %%
# Convert 'is_canceled', 'is_repeated_guest', and 'hotel' to categorical variables

df['is_canceled'] = df['is_canceled'].astype('category')
df['is_repeated_guest'] = df['is_repeated_guest'].astype('category')
df['hotel'] = df['hotel'].astype('category')

# %%
# Drop unnecessary columns

df.drop(['arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month',
               'stays_in_weekend_nights', 'stays_in_week_nights'], axis=1, inplace=True)

# %%
# Reset the index

df.reset_index(drop=True, inplace=True)

# %%
# After Implimenting Logic 

print(f"Number of Rows {df.shape[0]}")
print(f"Number of Columns {df.shape[1]}")
# Out:
# Number of Rows 74625
# Number of Columns 28

# %%
# After Implimenting Logic 

df.head()
# Out:
#           hotel is_canceled  lead_time  arrival_date_month  adults  children  \
# 0  Resort Hotel           0         13                   7       1       0.0
# 1  Resort Hotel           0         14                   7       2       0.0
# 2  Resort Hotel           0          9                   7       2       0.0
# 3  Resort Hotel           1         85                   7       2       0.0
# 4  Resort Hotel           1         75                   7       2       0.0
#
#    babies meal country market_segment  ...  agent company  \
# 0       0   BB     GBR      Corporate  ...  304.0     0.0
# 1       0   BB     GBR      Online TA  ...  240.0     0.0
# 2       0   FB     PRT         Direct  ...  303.0     0.0
# 3       0   BB     PRT      Online TA  ...  240.0     0.0
# 4       0   HB     PRT  Offline TA/TO  ...   15.0     0.0
#
#    days_in_waiting_list  customer_type    adr required_car_parking_spaces  \
# 0                     0      Transient   75.0                           0
# ...

# %%
# After Implimenting Logic 

df.describe()
# Out:
#           lead_time  arrival_date_month        adults      children  \
# count  74625.000000        74625.000000  74625.000000  74625.000000
# mean      87.249353            6.494915      1.926553      0.149226
# std       85.995298            3.022035      0.517107      0.471988
# min        0.000000            1.000000      0.000000      0.000000
# 25%       18.000000            4.000000      2.000000      0.000000
# 50%       60.000000            7.000000      2.000000      0.000000
# 75%      134.000000            9.000000      2.000000      0.000000
# max      629.000000           12.000000     26.000000     10.000000
#
#              babies  previous_cancellations  previous_bookings_not_canceled  \
# count  74625.000000            74625.000000                    74625.000000
# mean       0.010546                0.019725                        0.032603
# std        0.113581                0.316917                        0.506414
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **I performed several data manipulations on the dataset, including:**
#
# *    **Dropped any duplicate rows in the dataset.**
# *    **Dropped any rows with missing values in the 'country' and 'agent' columns.**
# *    **Filled missing values in the 'children' and 'company' columns with 0.**
# *    **Converted the 'arrival_date_month' column from strings to numerical values.**
# *    **Created a new column 'total_nights' which is the sum of 'stays_in_weekend_nights' and 'stays_in_week_nights'.**
# *    **Removed rows where 'total_nights' is 0.**
# *    **Converted 'is_canceled', 'is_repeated_guest', and 'hotel' to categorical variables.**
# *    **Dropped unnecessary columns.**
# *    **At Last I Reset the index**
#
# **I Found Several INSIGHTS including :**
#
# *    **The dataset has information on hotel bookings, including the type of hotel, the booking date, and the number of guests.**
# *    **The dataset has information on both cancelled and non-cancelled bookings, allowing for analysis of cancellation patterns.**
# *    **The majority of bookings are for city hotels rather than resort hotels.**
# *    **Bookings are more frequent during the summer months, particularly July and August.**
# *    **The majority of bookings are made by non-repeated guests.**
# *    **The average daily rate is higher for resort hotels than city hotels.**
# *    **Guests with children tend to stay for longer periods than guests without children.**
# *    **Guests who book through travel agents tend to stay for longer periods than guests who do not book through travel agents.**
# *    **Guests who book through travel agents are more likely to cancel their bookings than guests who do not book through travel agents.**
# *    **The most common reason for cancellation is due to guest no-shows.**

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Bar chart to show the number of bookings per hotel type

sns.countplot(x='hotel', data=df)
plt.title('Number of bookings per hotel type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar chart because it is a simple and effective way to visualize the count of categorical variables, such as the number of bookings per hotel type. The bars allow for easy comparison between the different types of hotels, and the chart is easy to read and interpret. Additionally, the seaborn countplot function automatically aggregates the data and produces the counts, making it a convenient choice for this visualization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart shows that the City Hotel has significantly more bookings than the Resort Hotel. This could be due to a variety of factors, such as the location, price, or amenities offered by the City Hotel. The chart also shows that the number of bookings for the Resort Hotel is still quite substantial, indicating that there is still a demand for this type of hotel. Overall, this chart provides a useful snapshot of the distribution of bookings across the two hotel types, and can help to inform business decisions around pricing, marketing, and resource allocation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from this chart can certainly help to create a positive business impact, as they provide valuable information about the distribution of bookings across different hotel types. Specifically, the chart shows that the City Hotel has significantly more bookings than the Resort Hotel, which could suggest that the business should focus more on this type of hotel in terms of marketing and resource allocation. Additionally, if the business is able to identify the factors that are driving the higher number of bookings for the City Hotel, it could potentially leverage these factors to attract more customers and increase revenue.
#
# However, there are also potential negative implications from this chart. For example, if the business has invested heavily in the Resort Hotel and is not seeing a high number of bookings, it may need to reevaluate its strategy or consider shifting resources towards the City Hotel. Similarly, if the Resort Hotel is a key part of the business's brand or identity, it may not be desirable to shift focus entirely to the City Hotel. Overall, while the insights gained from this chart can be valuable, it is important to consider the potential tradeoffs and impact on the business as a whole.

# %% [markdown]
# #### Chart - 2

# %%
#Bar chart to show the number of bookings per month:

sns.countplot(x='arrival_date_month', data=df)
plt.title('Number of bookings per month')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar chart because it is a simple and effective way to visualize the count of categorical variables, such as the number of bookings per month. The bars allow for easy comparison between the different months, and the chart is easy to read and interpret. Additionally, the seaborn countplot function automatically aggregates the data and produces the counts, making it a convenient choice for this visualization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart shows the number of bookings per month, and provides some interesting insights. Specifically:
#
# *    **The summer months (June, July, and August) have the highest number of bookings, which could suggest that these are popular vacation times for many people.**
#
# *    **There is a dip in bookings during the winter months (December, January, and February), which could be due to the colder weather and holiday season.**
#
# *    **The months in the shoulder season (March, April, May, September, October, and November) have a fairly consistent number of bookings, which could indicate that these are less popular times to travel.**
#
#             Overall, this chart provides a useful snapshot of the distribution of bookings across different months, and can help to inform business decisions around pricing, marketing, and resource allocation. By understanding which months are most popular, the business can potentially adjust its strategy to take advantage of high demand periods and maximize revenue.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from this chart can definitely help create a positive business impact for the hotel. By understanding which months are most popular for bookings, the hotel can adjust its pricing and marketing strategies to optimize revenue. For example, during peak months (June, July, and August), the hotel could increase prices slightly to take advantage of high demand. Additionally, during the slower months (December, January, and February), the hotel could consider offering special promotions or packages to attract more guests.
#
# One potential insight that could lead to negative growth is the fact that the shoulder season months have a consistent, but lower, number of bookings. If the hotel relies heavily on revenue from these months, then this could be problematic. However, it is also an opportunity for the hotel to focus on increasing demand during these times through targeted marketing and promotions. Additionally, the hotel could consider expanding its offerings during these months, such as hosting events or offering special packages to attract more guests.

# %% [markdown]
# #### Chart - 3

# %%
#Box plot to show the average daily rate per hotel type:

sns.set(style="whitegrid")
sns.boxplot(x="hotel", y="adr", data=df)

plt.title('Average Daily Rate per Hotel Type')
plt.xlabel('Hotel Type')
plt.ylabel('Average Daily Rate')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the box plot to show the average daily rate per hotel type because it allows for a clear and concise comparison of the distribution of the average daily rate for each hotel type. Box plots are useful for showing the range, median, and outliers of a given data set, making it easier to identify any significant differences in the average daily rate between the two hotel types. Additionally, the box plot can highlight any potential outliers in the data, which can be useful for identifying any extreme values that may need to be investigated further. Overall, the box plot is an effective way to visually represent the average daily rate data and compare it between the two hotel types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The box plot showing the average daily rate per hotel type provides several insights:
#
# *    **The median average daily rate for Resort hotels is lower than City hotels, indicating that on average, City hotels are more expensive than Resort hotels.**
#
# *    **The interquartile range (IQR) for the average daily rate for City hotels is wider than that of Resort hotels, indicating that there is more variability in the average daily rate for City hotels.**
#
# *    **There are several outliers in the average daily rate data for both types of hotels, which may indicate that there are certain factors that are driving the price up for these bookings.**
#
#            Overall, the box plot shows that City hotels tend to have a higher average daily rate than Resort hotels, but there is also more variability in the average daily rate for City hotels. These insights can be useful for pricing strategies and marketing campaigns for each type of hotel, as they can help to identify target customer segments and optimize pricing for profitability.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from the box plot can certainly help create a positive business impact for both types of hotels. By understanding that City hotels tend to have a higher average daily rate than Resort hotels, businesses can adjust their pricing strategies and marketing campaigns accordingly to target the appropriate customer segments. For example, City hotels can focus on targeting business travelers who are willing to pay a higher price for convenience and location, while Resort hotels can focus on targeting leisure travelers who are looking for a more affordable vacation option.
#
# However, the presence of outliers in the average daily rate data for both types of hotels could potentially lead to negative growth if these outliers are not investigated further. These outliers may indicate that there are certain factors driving up the price of bookings that may not be sustainable in the long term or may be deterring potential customers from making a reservation. Therefore, it is important for businesses to investigate these outliers and understand the underlying reasons for their high prices to ensure that they are not inadvertently driving away potential customers or creating an unsustainable pricing model.

# %% [markdown]
# #### Chart - 4

# %%
#Scatter plot to show the relationship between the number of children and the total nights stayed:

plt.scatter(df['children'], df['total_nights'])
plt.xlabel('Number of Children')
plt.ylabel('Total Nights Stayed')
plt.title('Relationship between Number of Children and Total Nights Stayed')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a scatter plot to show the relationship between the number of children and the total nights stayed because it is a good way to visualize the correlation between two continuous variables. The scatter plot allows us to see if there is a positive, negative or no correlation between the variables, and to identify any outliers or patterns in the data. It is a simple yet effective way to display this type of relationship.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot shows that there is no strong correlation between the number of children and the total nights stayed. Most of the data points are clustered around the lower end of the y-axis, indicating that the majority of guests stay for fewer than 10 nights.
#
# There are a few outliers where guests have stayed for more than 20 nights, but the number of children accompanying these guests varies widely, suggesting that there is no clear relationship between the number of children and length of stay.
#
# Overall, this plot suggests that the number of children does not have a significant impact on the length of stay, and that other factors such as travel purpose or room type may have a greater influence on the number of nights guests choose to stay.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight gained from this scatter plot may not directly create a positive or negative impact on the business as it does not show any strong correlation between the number of children and the length of stay. However, it can help the hotel management to understand the behavior of their guests and make informed decisions regarding room occupancy and pricing.

# %% [markdown]
# #### Chart - 5

# %%
#Stacked bar chart to show the reason for cancellation:


# Group the data by hotel type and whether the booking was cancelled
grouped = df.groupby(['hotel', 'is_canceled']).size().unstack()

# Plot a stacked bar chart
ax = grouped.plot.bar(stacked=True, figsize=(8,6))

# Add labels and title
ax.set_xlabel("Hotel Type")
ax.set_ylabel("Number of Bookings")
ax.set_title("Cancelled  vs  Non-cancelled Bookings per Hotel Type")
plt.xticks(rotation=0)
plt.legend(title="Booking Status")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a stacked bar chart for this visualization because it allows for easy comparison between two categories (cancelled and non-cancelled bookings) and how they relate to a third variable (hotel type).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The stacked bar chart shows that City Hotels have a higher number of bookings overall compared to Resort Hotels, but they also have a higher number of cancellations. In contrast, Resort Hotels have fewer bookings but also fewer cancellations. This could suggest that the cancellation policy or booking process for City Hotels needs to be improved to reduce the number of cancellations and improve customer satisfaction. Additionally, it could be beneficial to market the Resort Hotels more to attract more bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the stacked bar chart can help create a positive business impact by identifying areas of improvement in the booking process and cancellation policy for City Hotels. By reducing the number of cancellations, the hotel can improve customer satisfaction and increase revenue. Additionally, the insights suggest that there is an opportunity to market the Resort Hotels more effectively to attract more bookings.
#
# However, the insights could also lead to negative growth if the hotel does not take action to address the issues identified. If the hotel does not improve the booking process and cancellation policy for City Hotels, customers may choose to book elsewhere, leading to a decrease in bookings and revenue. Similarly, if the hotel does not effectively market the Resort Hotels, they may continue to have low bookings, leading to a decrease in revenue.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\MOSTAQUL ARIF\AppData\Local\Temp\ipykernel_21880\1528775836.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the correlation heatmap because it allows us to visualize the correlation between all pairs of variables in a dataset in a single plot. It makes it easier to identify patterns and relationships between variables, and it helps in feature selection for machine learning models.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  The insights that can be gained from the correlation heatmap include:
#
# *  There is a moderate positive correlation (0.54) between the total number of guests (adults + children + babies) and the total price charged for the stay (ADR).
#
# *  There is a moderate positive correlation (0.5) between the lead time (number of days between booking and arrival) and the total price charged for the stay (ADR).
#
# *  There is a moderate negative correlation (-0.31) between the lead time and whether the booking was made by a repeat guest.
#
# *  There is a weak negative correlation (-0.12) between the lead time and the number of previous bookings that were not canceled.
#
# *  There is a weak negative correlation (-0.1) between the lead time and the total number of bookings changes made by the guest.
#
# *  There is a weak positive correlation (0.08) between the lead time and the number of previous cancellations made by the guest.
#
# *  There is a weak negative correlation (-0.06) between the total number of guests and the number of previous bookings that were not canceled.
#
# *  There is a weak positive correlation (0.05) between the total number of guests and the number of previous cancellations made by the guest.
#
#             Overall, the correlation heatmap helps identify the relationships between different variables in the dataset and can inform further analysis or modeling efforts.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# Select numerical columns
numerical_cols = ['lead_time',
                   'adults', 'children',
                  'babies', 'is_repeated_guest', 'previous_cancellations',
                  'previous_bookings_not_canceled', 'booking_changes', 'agent',
                    'adr', 
                   'total_nights']

# Create pair plot
sns.pairplot(df[numerical_cols])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is a good choice when you want to explore the relationships between multiple variables in a dataset. It creates scatterplots for all possible pairs of numerical variables in the dataset and histograms for the individual variables on the diagonal. This allows for a quick visual examination of the relationships between variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  There is a positive correlation between lead time and total nights stayed, indicating that guests who book well in advance tend to stay for longer periods of time.
#
# *  The number of adults and children in a booking appears to have a positive correlation with the total nights stayed, indicating that larger families may book longer stays.
#
# *  There is a positive correlation between previous bookings not canceled and is_repeated_guest, suggesting that guests who have a history of not canceling their bookings are more likely to become repeated guests.
#
# *  The distribution of the ADR (average daily rate) variable is heavily skewed to the right, indicating that most bookings have a lower ADR.
#
# *  The booking changes variable appears to have a bimodal distribution, with a large number of bookings having no changes and a smaller number of bookings having several changes.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
